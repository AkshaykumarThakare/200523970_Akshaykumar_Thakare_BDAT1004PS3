# %% [markdown]
# # Data Programming - Problem Set 3

# %% [markdown]
# # Question 1:

# %% [markdown]
# **Step 1. Import the necessary libraries**

# %%
import numpy as np
import pandas as pd
import warnings
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# **Step 2. Import the dataset and Step 3. Assign it to a variable called users**

# %%
users = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user', sep = '|') #assigning dataset to variable users
users #printing users
# Out:
#      user_id  age gender     occupation zip_code
# 0          1   24      M     technician    85711
# 1          2   53      F          other    94043
# 2          3   23      M         writer    32067
# 3          4   24      M     technician    43537
# 4          5   33      F          other    15213
# ..       ...  ...    ...            ...      ...
# 938      939   26      F        student    33319
# 939      940   32      M  administrator    02215
# 940      941   20      M        student    97229
# 941      942   48      F      librarian    78209
# 942      943   22      M        student    77841
#
# [943 rows x 5 columns]

# %% [markdown]
# **Step 4. Discover what is the mean age per occupation**

# %%
# Importing necessary libraries
import pandas as pd  # Importing the pandas library and using the alias 'pd'
import seaborn as sns  # Importing the seaborn library and using the alias 'sns'
import matplotlib.pyplot as plt  # Importing the pyplot module from matplotlib and using the alias 'plt'

# Replacing 'your_data_url' with the actual URL of your CSV data
data_url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user'  # Specifying the URL of the CSV data
users = pd.read_csv(data_url, sep='|', index_col='user_id')  # Reading the CSV data into a pandas DataFrame

# Calculating the mean age per occupation using groupby and reset_index to obtain a DataFrame
mean_age_per_occupation = users.groupby('occupation')['age'].mean().reset_index()

# Setting the plotting style using seaborn
sns.set(style="whitegrid")

# Creating a bar plot with specified size
plt.figure(figsize=(20, 10))

# Creating a bar plot using seaborn, specifying data, and color palette
bar_plot = sns.barplot(x='occupation', y='age', data=mean_age_per_occupation, palette='deep')

# Rotating x-axis labels for better readability
plt.xticks(rotation=45, ha='right')

# Adding data labels (mean ages) on top of each bar
for index, value in enumerate(mean_age_per_occupation['age']):
    bar_plot.text(index, value + 0.1, f'{value:.2f}', ha='center', va='bottom', fontsize=18)

# Setting labels and title for the plot
bar_plot.set(xlabel='Occupation', ylabel='Mean Age', title='Mean Age per Occupation')

# Displaying the plot
plt.show()

# Printing the DataFrame showing mean age per occupation
print(mean_age_per_occupation)
# Out:
#        occupation        age
# 0   administrator  38.746835
# 1          artist  31.392857
# 2          doctor  43.571429
# 3        educator  42.010526
# 4        engineer  36.388060
# 5   entertainment  29.222222
# 6       executive  38.718750
# 7      healthcare  41.562500
# 8       homemaker  32.571429
# 9          lawyer  36.750000
# 10      librarian  40.000000
# 11      marketing  37.615385
# 12           none  26.555556
# 13          other  34.523810
# 14     programmer  33.121212
# 15        retired  63.071429
# 16       salesman  35.666667
# 17      scientist  35.548387
# 18        student  22.081633
# 19     technician  33.148148
# 20         writer  36.311111

# %% [markdown]
# **Step 5. Discover the Male ratio per occupation and sort it from the most to the least**

# %%
# Calculate the male ratio per occupation
male_ratio_per_occupation = users.groupby('occupation')['gender'].apply(lambda x: (x == 'M').mean()).reset_index()
male_ratio_per_occupation = male_ratio_per_occupation.rename(columns={'gender': 'male_ratio'})

# Sort by male ratio in descending order
male_ratio_per_occupation = male_ratio_per_occupation.sort_values(by='male_ratio', ascending=False)

# Display the result
print(male_ratio_per_occupation)
# Out:
#        occupation  male_ratio
# 2          doctor    1.000000
# 4        engineer    0.970149
# 19     technician    0.962963
# 15        retired    0.928571
# 14     programmer    0.909091
# 6       executive    0.906250
# 17      scientist    0.903226
# 5   entertainment    0.888889
# 9          lawyer    0.833333
# 16       salesman    0.750000
# 3        educator    0.726316
# 18        student    0.693878
# 13          other    0.657143
# 11      marketing    0.615385
# 20         writer    0.577778
# 12           none    0.555556
# 0   administrator    0.544304
# 1          artist    0.535714
# 10      librarian    0.431373
# 7      healthcare    0.312500
# 8       homemaker    0.142857

# %% [markdown]
# **Step 6. For each occupation, calculate the minimum and maximum ages**

# %%
users.groupby('occupation').age.agg(['min', 'max'])
# Out:
#                min  max
# occupation
# administrator   21   70
# artist          19   48
# doctor          28   64
# educator        23   63
# engineer        22   70
# entertainment   15   50
# executive       22   69
# healthcare      22   62
# homemaker       20   50
# lawyer          21   53
# librarian       23   69
# marketing       24   55
# none            11   55
# other           13   64
# programmer      20   63
# retired         51   73
# salesman        18   66
# scientist       23   55
# student          7   42
# technician      21   55
# writer          18   60

# %% [markdown]
# **Step 7. For each combination of occupation and sex, calculate the mean age**

# %%
# Grouping the 'users' DataFrame by 'occupation' and 'gender' columns, then calculating the mean age for each group
users.groupby(['occupation', 'gender']).age.mean()
# Out:
# occupation     gender
# administrator  F         40.638889
#                M         37.162791
# artist         F         30.307692
#                M         32.333333
# doctor         M         43.571429
# educator       F         39.115385
#                M         43.101449
# engineer       F         29.500000
#                M         36.600000
# entertainment  F         31.000000
#                M         29.000000
# executive      F         44.000000
#                M         38.172414
# healthcare     F         39.818182
#                M         45.400000
# homemaker      F         34.166667
#                M         23.000000
# lawyer         F         39.500000
#                M         36.200000
# librarian      F         40.000000
#                M         40.000000
# marketing      F         37.200000
#                M         37.875000
# none           F         36.500000
#                M         18.600000
# other          F         35.472222
# ...

# %% [markdown]
# **Step 8. For each occupation present the percentage of women and men**

# %%
gender_ocup = users.groupby(['occupation', 'gender']).agg({'gender': 'count'}) # Grouping the 'users' DataFrame by 'occupation' and 'gender', then aggregating the count of each gender within each occupation
occup_count = users.groupby(['occupation']).count() # Grouping users by occupation
occup_gender = gender_ocup.div(occup_count, level = "occupation") # Counting
occup_gender.loc[:, 'gender'] # Selecting Gender
# Out:
# occupation     gender
# administrator  F         0.455696
#                M         0.544304
# artist         F         0.464286
#                M         0.535714
# doctor         M         1.000000
# educator       F         0.273684
#                M         0.726316
# engineer       F         0.029851
#                M         0.970149
# entertainment  F         0.111111
#                M         0.888889
# executive      F         0.093750
#                M         0.906250
# healthcare     F         0.687500
#                M         0.312500
# homemaker      F         0.857143
#                M         0.142857
# lawyer         F         0.166667
#                M         0.833333
# librarian      F         0.568627
#                M         0.431373
# marketing      F         0.384615
#                M         0.615385
# none           F         0.444444
#                M         0.555556
# other          F         0.342857
#                M         0.657143
# ...

# %% [markdown]
# # Question 2:

# %% [markdown]
# **Step 1. Import the necessary libraries**

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# **Step 2. Import the dataset and Step 3. Assign it to a variable called euro12**

# %%
euro = pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/02_Filtering_%26_Sorting/Euro12/Euro_2012_stats_TEAM.csv')
euro
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %% [markdown]
# **Step 4. Select only the Goal column**

# %%
euro.Goals
# Out:
# 0      4
# 1      4
# 2      4
# 3      5
# 4      3
# 5     10
# 6      5
# 7      6
# 8      2
# 9      2
# 10     6
# 11     1
# 12     5
# 13    12
# 14     5
# 15     2
# Name: Goals, dtype: int64

# %% [markdown]
# **Step 5. How many team participated in the Euro2012?**

# %%
# Counting the number of unique teams in the 'Team' column
num_teams_participated = len(euro['Team'].unique())
# Printing the result
print(f"The number of teams that participated in Euro 2012 is: {num_teams_participated}")
# Out:
# The number of teams that participated in Euro 2012 is: 16

# %% [markdown]
# **Step 6. What is the number of columns in the dataset?**

# %%
number_of_columns = euro.shape[1] #Number of columns using the shape attribute
# Print the result
print(f"The number of columns in the dataset is: {number_of_columns}")
# Out:
# The number of columns in the dataset is: 35

# %% [markdown]
# **Step 7. View only the columns Team, Yellow Cards and Red Cards and assign them to a dataframe called discipline**

# %%
discipline = euro[['Team', 'Yellow Cards', 'Red Cards']] # Viewing specific columns
discipline
# Out:
#                    Team  Yellow Cards  Red Cards
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 2               Denmark             4          0
# 3               England             5          0
# 4                France             6          0
# 5               Germany             4          0
# 6                Greece             9          1
# 7                 Italy            16          0
# 8           Netherlands             5          0
# 9                Poland             7          1
# 10             Portugal            12          0
# 11  Republic of Ireland             6          1
# 12               Russia             6          0
# 13                Spain            11          0
# 14               Sweden             7          0
# 15              Ukraine             5          0

# %% [markdown]
# **Step 8. Sort the teams by Red Cards, then to Yellow Cards**

# %%
discipline.sort_values(by=['Red Cards'])
discipline.sort_values(by=['Yellow Cards'])
discipline
# Out:
#                    Team  Yellow Cards  Red Cards
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 2               Denmark             4          0
# 3               England             5          0
# 4                France             6          0
# 5               Germany             4          0
# 6                Greece             9          1
# 7                 Italy            16          0
# 8           Netherlands             5          0
# 9                Poland             7          1
# 10             Portugal            12          0
# 11  Republic of Ireland             6          1
# 12               Russia             6          0
# 13                Spain            11          0
# 14               Sweden             7          0
# 15              Ukraine             5          0

# %% [markdown]
# **Step 9. Calculate the mean Yellow Cards given per Team**

# %%
mean_yellow_card=discipline['Yellow Cards'].mean()
print("Mean for Yellow Card team is :", mean_yellow_card)
# Out:
# Mean for Yellow Card team is : 7.4375

# %% [markdown]
# **Step 10. Filter teams that scored more than 6 goals**

# %%
euro[euro['Goals'] > 6]
# Out:
#        Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5   Germany     10               32                32             47.8%
# 13    Spain     12               42                33             55.9%
#
#    % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5             15.6%                          80             2              1
# 13            16.0%                         100             0              1
#
#     Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 5                      0  ...          10                 62.6%         63
# 13                     0  ...          15                 93.8%        102
#
#    Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 5              49        12             4          0       15        15
# 13             83        19            11          0       17        17
#
#     Players Used
# 5             17
# 13            18
#
# ...

# %% [markdown]
# **Step 11. Select the teams that start
# with G**

# %%
euro[euro.Team.str.startswith('G')]
# Out:
#       Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5  Germany     10               32                32             47.8%
# 6   Greece      5                8                18             30.7%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5            15.6%                          80             2              1
# 6            19.2%                          32             1              1
#
#    Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 5                     0  ...          10                 62.6%         63
# 6                     1  ...          13                 65.1%         67
#
#   Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 5             49        12             4          0       15        15
# 6             48        12             9          1       12        12
#
#    Players Used
# 5            17
# 6            20
#
# [2 rows x 35 columns]

# %% [markdown]
# **Step 12. Select the first 7 columns**

# %%
euro.head(7)
# Out:
#              Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 0         Croatia      4               13                12             51.9%
# 1  Czech Republic      4               13                18             41.9%
# 2         Denmark      4               10                10             50.0%
# 3         England      5               11                18             50.0%
# 4          France      3               22                24             37.9%
# 5         Germany     10               32                32             47.8%
# 6          Greece      5                8                18             30.7%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 0            16.0%                          32             0              0
# 1            12.9%                          39             0              0
# 2            20.0%                          27             1              0
# ...

# %% [markdown]
# **Step 13. Select all columns except the last 3**

# %%
euro.iloc[:, :-3]
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %% [markdown]
# Step 14. Present only the Shooting Accuracy from England, Italy and Russia

# %%
selected_teams = ['England', 'Italy', 'Russia'] # List of teams selected
selected_shooting_accuracy = euro[euro['Team'].isin(selected_teams)]['Shooting Accuracy'] # Filtering data as per Shooting Accuracy
print(selected_shooting_accuracy)
# Out:
# 3     50.0%
# 7     43.0%
# 12    22.5%
# Name: Shooting Accuracy, dtype: object

# %% [markdown]
# # Question 3

# %% [markdown]
# **Step 1. Import the necessary libraries**

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# **Step 2. Create 3 differents Series, each of length 100, as follows:**

# %% [markdown]
# *1) The first a random number from 1 to 4*

# %% [markdown]
# *2) The second a random number from 1 to 3*

# %% [markdown]
# *3) The third a random number from 10,000 to 30,000*

# %%
s1 = pd.Series(np.random.randint(1, high=5, size=100, dtype='l'))
s2 = pd.Series(np.random.randint(1, high=4, size=100, dtype='l'))
s3 = pd.Series(np.random.randint(10000, high=30001, size=100, dtype='l'))
print(s1, s2, s3)
# Out:
# 0     4
# 1     4
# 2     3
# 3     1
# 4     4
#      ..
# 95    2
# 96    1
# 97    2
# 98    2
# 99    3
# Length: 100, dtype: int32 0     3
# 1     2
# 2     1
# 3     1
# 4     2
#      ..
# 95    1
# 96    3
# 97    2
# 98    3
# 99    3
# Length: 100, dtype: int32 0     17717
# 1     29282
# 2     21279
# 3     28181
# 4     25458
#       ...
# 95    19867
# 96    29708
# 97    16557
# 98    23510
# 99    14589
# Length: 100, dtype: int32

# %% [markdown]
# **Step 3. Create a DataFrame by joinning the Series by column**

# %%
housemkt = pd.concat([s1, s2, s3], axis=1)
housemkt.head()
# Out:
#    0  1      2
# 0  4  3  17717
# 1  4  2  29282
# 2  3  1  21279
# 3  1  1  28181
# 4  4  2  25458

# %% [markdown]
# **Step 4. Change the name of the columns to bedrs, bathrs, price_sqr_meter**

# %%
housemkt.rename(columns = {0: 'bedrs', 1: 'bathrs', 2: 'price_sqr_meter'}, inplace=True)
housemkt.head()
# Out:
#    bedrs  bathrs  price_sqr_meter
# 0      4       3            17717
# 1      4       2            29282
# 2      3       1            21279
# 3      1       1            28181
# 4      4       2            25458

# %% [markdown]
# **Step 5. Create a one column DataFrame with the values of the 3 Series and assign it to 'bigcolumn'**

# %%
bigcolumn = pd.concat([s1, s2, s3], axis=0)
bigcolumn = bigcolumn.to_frame()
print(type(bigcolumn))
bigcolumn
# Out:
# <class 'pandas.core.frame.DataFrame'>
#         0
# 0       4
# 1       4
# 2       3
# 3       1
# 4       4
# ..    ...
# 95  19867
# 96  29708
# 97  16557
# 98  23510
# 99  14589
#
# [300 rows x 1 columns]

# %% [markdown]
# **Step 6. Ops it seems it is going only until index 99. Is it true?**

# %%
print(len(bigcolumn))
# Checking if it's going only until index 99
print(bigcolumn.index.max() == 99)  # This code will print True if the index goes only until 99
# Out:
# 300
# True

# %% [markdown]
# **Step 7. Reindex the DataFrame so it goes from 0 to 299**

# %%
bigcolumn.reset_index(drop=True, inplace=True)
bigcolumn
# Out:
#          0
# 0        4
# 1        4
# 2        3
# 3        1
# 4        4
# ..     ...
# 295  19867
# 296  29708
# 297  16557
# 298  23510
# 299  14589
#
# [300 rows x 1 columns]

# %% [markdown]
# # Question 4:

# %% [markdown]
# **Step 1. Import the necessary libraries**

# %%
import pandas as pd
import numpy as np
import datetime

# %% [markdown]
# **Step 2. Import the dataset from the attached file wind.txt and Step 3. Assign it to a variable called data and replace the first 3 columns by a proper
# datetime index.**

# %%
wind_data = pd.read_csv('wind.txt', sep = "\s+", parse_dates = [[0,1,2]]) 
wind_data.head()
# Out:
#     Yr_Mo_Dy    RPT    VAL    ROS    KIL    SHA   BIR    DUB    CLA    MUL  \
# 0 2061-01-01  15.04  14.96  13.17   9.29    NaN  9.87  13.67  10.25  10.83
# 1 2061-01-02  14.71    NaN  10.83   6.50  12.62  7.67  11.50  10.04   9.79
# 2 2061-01-03  18.50  16.88  12.33  10.13  11.17  6.17  11.25    NaN   8.50
# 3 2061-01-04  10.58   6.63  11.75   4.58   4.54  2.88   8.63   1.79   5.83
# 4 2061-01-05  13.33  13.25  11.42   6.17  10.71  8.21  11.92   6.54  10.92
#
#      CLO    BEL    MAL
# 0  12.58  18.50  15.04
# 1   9.67  17.54  13.83
# 2   7.67  12.75  12.71
# 3   5.88   5.46  10.88
# 4  10.34  12.92  11.83

# %% [markdown]
# **Step 4. Year 2061? Do we really have data from this year? Create a function to fix it and apply it.**

# %%
def fix_year(x):
  year = x.year - 100 if x.year > 1989 else x.year
  return datetime.date(year, x.month, x.day)
wind_data['Yr_Mo_Dy'] = wind_data['Yr_Mo_Dy'].apply(fix_year)
wind_data.head()
# Out:
#      Yr_Mo_Dy    RPT    VAL    ROS    KIL    SHA   BIR    DUB    CLA    MUL  \
# 0  1961-01-01  15.04  14.96  13.17   9.29    NaN  9.87  13.67  10.25  10.83
# 1  1961-01-02  14.71    NaN  10.83   6.50  12.62  7.67  11.50  10.04   9.79
# 2  1961-01-03  18.50  16.88  12.33  10.13  11.17  6.17  11.25    NaN   8.50
# 3  1961-01-04  10.58   6.63  11.75   4.58   4.54  2.88   8.63   1.79   5.83
# 4  1961-01-05  13.33  13.25  11.42   6.17  10.71  8.21  11.92   6.54  10.92
#
#      CLO    BEL    MAL
# 0  12.58  18.50  15.04
# 1   9.67  17.54  13.83
# 2   7.67  12.75  12.71
# 3   5.88   5.46  10.88
# 4  10.34  12.92  11.83

# %% [markdown]
# Step 5. Set the right dates as the index. Pay attention at the data type, it should be datetime64[ns].

# %%
wind_data["Yr_Mo_Dy"] = pd.to_datetime(wind_data["Yr_Mo_Dy"])
wind_data = wind_data.set_index('Yr_Mo_Dy')
wind_data.head()
# Out:
#               RPT    VAL    ROS    KIL    SHA   BIR    DUB    CLA    MUL  \
# Yr_Mo_Dy
# 1961-01-01  15.04  14.96  13.17   9.29    NaN  9.87  13.67  10.25  10.83
# 1961-01-02  14.71    NaN  10.83   6.50  12.62  7.67  11.50  10.04   9.79
# 1961-01-03  18.50  16.88  12.33  10.13  11.17  6.17  11.25    NaN   8.50
# 1961-01-04  10.58   6.63  11.75   4.58   4.54  2.88   8.63   1.79   5.83
# 1961-01-05  13.33  13.25  11.42   6.17  10.71  8.21  11.92   6.54  10.92
#
#               CLO    BEL    MAL
# Yr_Mo_Dy
# 1961-01-01  12.58  18.50  15.04
# 1961-01-02   9.67  17.54  13.83
# 1961-01-03   7.67  12.75  12.71
# 1961-01-04   5.88   5.46  10.88
# 1961-01-05  10.34  12.92  11.83

# %% [markdown]
# **Step 6. Compute how many values are missing for each location over the entire record.They should be ignored in all calculations below**

# %%
wind_data.isnull().sum()
# Out:
# RPT    6
# VAL    3
# ROS    2
# KIL    5
# SHA    2
# BIR    0
# DUB    3
# CLA    2
# MUL    3
# CLO    1
# BEL    0
# MAL    4
# dtype: int64

# %% [markdown]
# **Step 7. Compute how many non-missing values there are in total.**

# %%
wind_data.shape[0] - wind_data.isnull().sum()
wind_data.notnull().sum()
# Out:
# RPT    6568
# VAL    6571
# ROS    6572
# KIL    6569
# SHA    6572
# BIR    6574
# DUB    6571
# CLA    6572
# MUL    6571
# CLO    6573
# BEL    6574
# MAL    6570
# dtype: int64

# %% [markdown]
# **Step 8. Calculate the mean windspeeds of the windspeeds over all the locations and all the times.**

# %%
wind_data.sum().sum() / wind_data.notna().sum().sum()
# Out:
# 10.227883764282181

# %% [markdown]
# **Step 9. Create a DataFrame called loc_stats and calculate the min, max and mean windspeeds and standard deviations of the windspeeds at each location over all the days**

# %%
wind_data.describe(percentiles=[])
# Out:
#                RPT          VAL          ROS          KIL          SHA  \
# count  6568.000000  6571.000000  6572.000000  6569.000000  6572.000000
# mean     12.362987    10.644314    11.660526     6.306468    10.455834
# std       5.618413     5.267356     5.008450     3.605811     4.936125
# min       0.670000     0.210000     1.500000     0.000000     0.130000
# 50%      11.710000    10.170000    10.920000     5.750000     9.960000
# max      35.800000    33.370000    33.840000    28.460000    37.540000
#
#                BIR          DUB          CLA          MUL          CLO  \
# count  6574.000000  6571.000000  6572.000000  6571.000000  6573.000000
# mean      7.092254     9.797343     8.495053     8.493590     8.707332
# std       3.968683     4.977555     4.499449     4.166872     4.503954
# min       0.000000     0.000000     0.000000     0.000000     0.040000
# 50%       6.830000     9.210000     8.080000     8.170000     8.290000
# ...

# %% [markdown]
# **Step 10. Create a DataFrame called day_stats and calculate the min, max and mean windspeed and standard deviations of the windspeeds across all the locations at each day**

# %%
day_stats = pd.DataFrame()
day_stats['min'] = wind_data.min(axis = 1)
day_stats['max'] = wind_data.max(axis = 1)
day_stats['mean'] = wind_data.mean(axis = 1)
day_stats['std'] = wind_data.std(axis = 1)
day_stats.head()
# Out:
#              min    max       mean       std
# Yr_Mo_Dy
# 1961-01-01  9.29  18.50  13.018182  2.808875
# 1961-01-02  6.50  17.54  11.336364  3.188994
# 1961-01-03  6.17  18.50  11.641818  3.681912
# 1961-01-04  1.79  11.75   6.619167  3.198126
# 1961-01-05  6.17  13.33  10.630000  2.445356

# %% [markdown]
# **Step 11. Find the average windspeed in January for each location.**

# %%
wind_data.loc[wind_data.index.month == 1].mean()
# Out:
# RPT    14.847325
# VAL    12.914560
# ROS    13.299624
# KIL     7.199498
# SHA    11.667734
# BIR     8.054839
# DUB    11.819355
# CLA     9.512047
# MUL     9.543208
# CLO    10.053566
# BEL    14.550520
# MAL    18.028763
# dtype: float64

# %% [markdown]
# **Step 12. Downsample the record to a yearly frequency for each location.**

# %%
wind_data.groupby(wind_data.index.to_period('A')).mean()
# Out:
#                 RPT        VAL        ROS       KIL        SHA       BIR  \
# Yr_Mo_Dy
# 1961      12.299583  10.351796  11.362369  6.958227  10.881763  7.729726
# 1962      12.246923  10.110438  11.732712  6.960440  10.657918  7.393068
# 1963      12.813452  10.836986  12.541151  7.330055  11.724110  8.434712
# 1964      12.363661  10.920164  12.104372  6.787787  11.454481  7.570874
# 1965      12.451370  11.075534  11.848767  6.858466  11.024795  7.478110
# 1966      13.461973  11.557205  12.020630  7.345726  11.805041  7.793671
# 1967      12.737151  10.990986  11.739397  7.143425  11.630740  7.368164
# 1968      11.835628  10.468197  11.409754  6.477678  10.760765  6.067322
# 1969      11.166356   9.723699  10.902000  5.767973   9.873918  6.189973
# 1970      12.600329  10.726932  11.730247  6.217178  10.567370  7.609452
# 1971      11.273123   9.095178  11.088329  5.241507   9.440329  6.097151
# 1972      12.463962  10.561311  12.058333  5.929699   9.430410  6.358825
# ...

# %% [markdown]
# **Step 13. Downsample the record to a monthly frequency for each location.**

# %%
wind_data.groupby(wind_data.index.to_period('M')).mean()
# Out:
#                 RPT        VAL        ROS       KIL        SHA        BIR  \
# Yr_Mo_Dy
# 1961-01   14.841333  11.988333  13.431613  7.736774  11.072759   8.588065
# 1961-02   16.269286  14.975357  14.441481  9.230741  13.852143  10.937500
# 1961-03   10.890000  11.296452  10.752903  7.284000  10.509355   8.866774
# 1961-04   10.722667   9.427667   9.998000  5.830667   8.435000   6.495000
# 1961-05    9.860968   8.850000  10.818065  5.905333   9.490323   6.574839
# ...             ...        ...        ...       ...        ...        ...
# 1978-08    9.645161   8.259355   9.032258  4.502903   7.368065   5.935161
# 1978-09   10.913667  10.895000  10.635000  5.725000  10.372000   9.278333
# 1978-10    9.897742   8.670968   9.295806  4.721290   8.525161   6.774194
# 1978-11   16.151667  14.802667  13.508000  7.317333  11.475000   8.743000
# 1978-12   16.175484  13.748065  15.635161  7.094839  11.398710   9.241613
#
# ...

# %% [markdown]
# **Step 14. Downsample the record to a weekly frequency for each location**

# %%
wind_data.groupby(wind_data.index.to_period('W')).mean()
# Out:
#                              RPT        VAL        ROS        KIL        SHA  \
# Yr_Mo_Dy
# 1960-12-26/1961-01-01  15.040000  14.960000  13.170000   9.290000        NaN
# 1961-01-02/1961-01-08  13.541429  11.486667  10.487143   6.417143   9.474286
# 1961-01-09/1961-01-15  12.468571   8.967143  11.958571   4.630000   7.351429
# 1961-01-16/1961-01-22  13.204286   9.862857  12.982857   6.328571   8.966667
# 1961-01-23/1961-01-29  19.880000  16.141429  18.225714  12.720000  17.432857
# ...                          ...        ...        ...        ...        ...
# 1978-11-27/1978-12-03  14.934286  11.232857  13.941429   5.565714  10.215714
# 1978-12-04/1978-12-10  20.740000  19.190000  17.034286   9.777143  15.287143
# 1978-12-11/1978-12-17  16.758571  14.692857  14.987143   6.917143  11.397143
# 1978-12-18/1978-12-24  11.155714   8.008571  13.172857   4.004286   7.825714
# 1978-12-25/1978-12-31  14.951429  11.801429  16.035714   6.507143   9.660000
#
# ...

# %% [markdown]
# **Step 15. Calculate the min, max and mean windspeeds and standard deviations of the windspeeds across all locations for each week (assume that the first week starts on January 2 1961) for the first 52 weeks.**

# %%
weekly = wind_data.resample('W').agg(['min','max','mean','std'])
weekly.loc[weekly.index[1:53], "RPT":"MAL"] .head(10)
# Out:
#               RPT                                VAL                    \
#               min    max       mean       std    min    max       mean
# Yr_Mo_Dy
# 1961-01-08  10.58  18.50  13.541429  2.631321   6.63  16.88  11.486667
# 1961-01-15   9.04  19.75  12.468571  3.555392   3.54  12.08   8.967143
# 1961-01-22   4.92  19.83  13.204286  5.337402   3.42  14.37   9.862857
# 1961-01-29  13.62  25.04  19.880000  4.619061   9.96  23.91  16.141429
# 1961-02-05  10.58  24.21  16.827143  5.251408   9.46  24.21  15.460000
# 1961-02-12  16.00  24.54  19.684286  3.587677  11.54  21.42  16.417143
# 1961-02-19   6.04  22.50  15.130000  5.064609  11.63  20.17  15.091429
# 1961-02-26   7.79  25.80  15.221429  7.020716   7.08  21.50  13.625714
# 1961-03-05  10.96  13.33  12.101429  0.997721   8.83  17.00  12.951429
# 1961-03-12   4.88  14.79   9.376667  3.732263   8.08  16.96  11.578571
#
#                         ROS         ...        CLO              BEL         \
# ...

# %% [markdown]
# # Question 5:

# %% [markdown]
# **Step 1. Import the necessary libraries**

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# **Step 2. Import the dataset from this address and Step 3. Assign it to a variable called chipo.**

# %%
url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv'
chipo = pd.read_csv(url, sep = '\t')

# %% [markdown]
# **Step 4. See the first 10 entries**

# %%
chipo.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %% [markdown]
# **Step 5. What is the number of observations in the dataset?**

# %%
num_observations=chipo.shape[0]
# Print the result
print("The number of observations in the dataset is:", num_observations)
# Out:
# The number of observations in the dataset is: 4622

# %% [markdown]
# **Step 6. What is the number of columns in the dataset?**

# %%
num_columns=chipo.shape[1]
#Print the result
print("The number of columns in the dataset is:",num_columns)
# Out:
# The number of columns in the dataset is: 5

# %% [markdown]
# **Step 7. Print the name of all the columns.**

# %%
column_names=chipo.columns
# Print the result
print("Column names:")
for column_name in column_names:
    print(column_name)
# Out:
# Column names:
# order_id
# quantity
# item_name
# choice_description
# item_price

# %% [markdown]
# **Step 8. How is the dataset indexed?**

# %%
indexed=chipo.index
# Print the result
print("Index information:")
print(indexed)
# Out:
# Index information:
# RangeIndex(start=0, stop=4622, step=1)

# %% [markdown]
# **Step 9. Which was the most-ordered item?**

# %%
c = chipo.groupby('item_name').sum()
c = c.sort_values(['quantity'], ascending = False)
c.head(2)
# Out:
#                  order_id  quantity
# item_name
# Chicken Bowl       713926       761
# Chicken Burrito    497303       591

# %% [markdown]
# **Step 10. For the most-ordered item, how many items were ordered?**

# %%
print('For the most-ordered item, ordered were:',str(713926))
# Out:
# For the most-ordered item, ordered were: 713926

# %% [markdown]
# **Step 11. What was the most ordered item in the choice_description column?**

# %%
d = chipo.groupby('choice_description').sum()
d = d.sort_values(['quantity'], ascending = False)
d.head(2)
# Out:
#                     order_id  quantity
# choice_description
# [Diet Coke]           123455       159
# [Coke]                122752       143

# %% [markdown]
# **Step 12. How many items were ordered in total?**

# %%
total_items_ordered = chipo.quantity.sum()
print("Total items ordered are:", total_items_ordered)
# Out:
# Total items ordered are: 4972

# %% [markdown]
# **Step 13.**

# %% [markdown]
# **1. Turn the item price into a float**

# %%
try:
    dollarizer = lambda x: float(x[1:-1])
    chipo.item_price = chipo.item_price.apply(dollarizer)
    
except:TypeError

# %% [markdown]
# **2. Check the item price type**

# %%
chipo.item_price.dtype
# Out:
# dtype('float64')

# %% [markdown]
# **3. Create a lambda function and change the type of item price**

# %%
# Create a lambda function to convert 'item_price' to float
convert_to_float_lambda = lambda x: float(x.replace('$', '')) if isinstance(x, str) else x
# Apply the lambda function to the 'item_price' column
chipo['item_price'] = chipo['item_price'].apply(convert_to_float_lambda)

# %% [markdown]
# **4. Check the item price type**

# %%
# Check the item price type after using the lambda function
print(f"Type of 'item_price' after using lambda function: {type(chipo['item_price'][0])}")
# Out:
# Type of 'item_price' after using lambda function: <class 'numpy.float64'>

# %% [markdown]
# **Step 14. How much was the revenue for the period in the dataset?**

# %%
revenue = (chipo['quantity'] * chipo['item_price']).sum()
print('Revenue was: $' + str(np.round(revenue,2)))
# Out:
# Revenue was: $39237.02

# %% [markdown]
# **Step 15. How many orders were made in the period?**

# %%
orders = chipo.order_id.value_counts().count()
print("Number of orders are:" ,orders)
# Out:
# Number of orders are: 1834

# %% [markdown]
# **Step 16. What is the average revenue amount per order?**

# %%
chipo['revenue'] = chipo['quantity'] * chipo['item_price']
d = order_grouped = chipo.groupby(by=['order_id']).sum()
order_grouped.mean()['revenue']
# Out:
# 21.394231188658654

# %% [markdown]
# **Step 17. How many different items are sold?**

# %%
chipo.item_name.value_counts().count()
# Out:
# 50

# %% [markdown]
# # Question 6:

# %% [markdown]
# **Create a line plot showing the number of marriages and divorces per capita in the U.S. between 1867 and 2014. Label both lines and show the legend. Don't forget to label your axes!**

# %%
import pandas as pd
import matplotlib.pyplot as plt

marriage_divorce_data = pd.read_csv('us-marriages-divorces-1867-2014.csv')

# Creatinf a line plot for marriages and divorces per capita
plt.figure(figsize=(12, 8))

# Ploting marriages per capita
plt.plot(marriage_divorce_data['Year'], marriage_divorce_data['Marriages'], label='Marriages per Capita', color='blue', marker='o')

# Ploting divorces per capita
plt.plot(marriage_divorce_data['Year'], marriage_divorce_data['Divorces'], label='Divorces per Capita', color='red', marker='o')

# Setting title and labels
plt.title('Number of Marriages and Divorces Per Capita in the U.S. (1867-2014)')
plt.xlabel('Year')
plt.ylabel('Per Capita Rate')

# Displaying legends
plt.legend()

# Adding grid for better readability
plt.grid(True, linestyle='--', alpha=0.7)

# Displaying the plot
plt.show()

# %% [markdown]
# # Question 7:

# %% [markdown]
# **Create a vertical bar chart comparing the number of marriages and divorces per capita in the U.S. between 1900, 1950, and 2000.**

# %%
import pandas as pd

us_marriage_divorce_data = pd.read_csv('us-marriages-divorces-1867-2014.csv')
# Filtering data for the years 1900, 1950, and 2000
selected_years = [1900, 1950, 2000]
selected_data = marriage_divorce_data[marriage_divorce_data['Year'].isin(selected_years)]

# Creating a vertical bar chart for marriages and divorces per capita
plt.figure(figsize=(20, 12))

bar_width = 1
bar_positions_marriages = selected_data['Year'] - bar_width / 2
bar_positions_divorces = selected_data['Year'] + bar_width / 2

# Ploting marriages per capita
plt.bar(bar_positions_marriages, selected_data['Marriages'], width=bar_width, label='Marriages per Capita', color='blue')

# Ploting divorces per capita
plt.bar(bar_positions_divorces, selected_data['Divorces'], width=bar_width, label='Divorces per Capita', color='red')

# Setting title and labels
plt.title('Comparison of Marriages and Divorces Per Capita in the U.S. (1900, 1950, 2000)')
plt.xlabel('Year')
plt.ylabel('Per Capita Rate')

# Displaying legends
plt.legend()

# Adding grid for better readability
plt.grid(True, linestyle='--', alpha=0.7)

# Setting x-axis ticks and labels
plt.xticks(selected_data['Year'], selected_data['Year'])

# Displaying the plot
plt.show()

# %% [markdown]
# # Question 8:

# %% [markdown]
# **Create a horizontal bar chart that compares the deadliest actors in Hollywood. Sort the actors by their kill count and label each bar with the corresponding actor's name.**

# %%
hollywood_actor_kills = pd.read_csv('actor_kill_counts.csv')
print(hollywood_actor_kills.columns)
# Out:
# Index(['Actor', 'Count'], dtype='object')

# %%
import pandas as pd

hollywood_actor_kills = pd.read_csv('actor_kill_counts.csv')
# Sortting the DataFrame by kill count in descending order
sorted_actors_data = hollywood_actor_kills.sort_values(by='Count', ascending=True)

# Creating a horizontal bar chart for the deadliest actors
plt.figure(figsize=(10, 8))

# Plotting the horizontal bars
bars = plt.barh(sorted_actors_data['Actor'], sorted_actors_data['Count'], color='red', edgecolor='black')

# Labeling each bar with the corresponding actor's name
for bar in bars:
    plt.text(bar.get_width(), bar.get_y() + bar.get_height()/2, f"{bar.get_width():,.0f}",
             va='center', ha='left', fontsize=10, color='black')

# Setting title and labels
plt.title('Deadliest Actors in Hollywood')
plt.xlabel('Kill Count')
plt.ylabel('Actor')

# Adding grid for better readability
plt.grid(axis='x', linestyle='--', alpha=0.7)

# Displaying the plot
plt.show()

# %% [markdown]
# # Question 9:

# %% [markdown]
# **Create a pie chart showing the fraction of all Roman Emperors that were assassinated. Make sure that the pie chart is an even circle, labels the categories, and shows the percentage breakdown of the categories.**

# %%
roman_emperors = pd.read_csv('roman-emperor-reigns.csv')
print(roman_emperors.columns)
# Out:
# Index(['Emperor', 'Length_of_Reign', 'Cause_of_Death'], dtype='object')

# %%
import pandas as pd
import matplotlib.pyplot as plt

roman_emperors = pd.read_csv('roman-emperor-reigns.csv')
# Checking if 'Cause_of_Death' contains 'assassinated' and creating a new column 'Assassinated'
roman_emperors['Assassinated'] = roman_emperors['Cause_of_Death'].str.contains('assassinated', case=False)

# Calculating the fraction of assassinated emperors
assassinated_fraction = roman_emperors['Assassinated'].mean()

# Creating a pie chart
plt.figure(figsize=(8, 8))

# Defining colors
colors = ['lightcoral', 'lightblue']

# Plotting the pie chart with labels, percentage breakdown, and other properties
plt.pie([assassinated_fraction, 1 - assassinated_fraction], labels=['Assassinated', 'Not Assassinated'],
        autopct='%1.1f%%', colors=colors, startangle=90, wedgeprops=dict(width=0.4), textprops={'fontsize': 12})

# Setting the title
plt.title('Fraction of Roman Emperors that were Assassinated', fontsize=14)

# Ensuring equal aspect ratio for a circular pie chart
plt.axis('equal')

# Displaying the plot
plt.show()

# %% [markdown]
# # Question 10:

# %% [markdown]
# **Create a scatter plot showing the relationship between the total revenue earned by arcades and the number of Computer Science PhDs awarded in the U.S. between 2000 and 2009.**

# %%
arcade_revenue_cs_doctorates = pd.read_csv('arcade-revenue-vs-cs-doctorates.csv')
print(arcade_revenue_cs_doctorates.columns)
# Out:
# Index(['Year', 'Total Arcade Revenue (billions)',
#        'Computer Science Doctorates Awarded (US)'],
#       dtype='object')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm

arcade_revenue_cs_doctorates = pd.read_csv('arcade-revenue-vs-cs-doctorates.csv')
# Create a scatter plot with Seaborn
plt.figure(figsize=(12, 8))
scatter_plot = sns.scatterplot(x='Total Arcade Revenue (billions)', 
                               y='Computer Science Doctorates Awarded (US)', 
                               hue='Year', 
                               data=arcade_revenue_cs_doctorates, 
                               palette='viridis',
                               size='Year',
                               sizes=(100, 200),
                               alpha=0.8)

# Set plot title and labels
plt.title('Relationship between Arcade Revenue and CS Doctorates (2000-2009)')
plt.xlabel('Total Arcade Revenue (billions)')
plt.ylabel('Computer Science Doctorates Awarded (US)')

# Display the legend
plt.legend(title='Year', loc='upper left', bbox_to_anchor=(1, 1))

# Improve grid visibility
plt.grid(True, linestyle='--', alpha=0.6)

# Show the plot
plt.show()
